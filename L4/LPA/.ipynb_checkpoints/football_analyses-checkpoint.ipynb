# %%
# igraph
import igraph
g = igraph.Graph.Read_GML('./football.gml')
igraph.plot(g)
print(g.community_label_propagation())
# Out:
# Clustering with 115 elements and 7 clusters
# [0] 0, 4, 9, 16, 23, 41, 93, 104
# [1] 1, 25, 33, 37, 45, 89, 103, 105, 109
# [2] 2, 6, 12, 13, 14, 15, 18, 26, 31, 32, 34, 36, 38, 39, 42, 43, 47, 54, 60,
#     61, 64, 71, 85, 99, 100, 106
# [3] 3, 5, 10, 11, 24, 28, 40, 44, 46, 48, 49, 50, 52, 53, 57, 58, 59, 63, 66,
#     67, 69, 72, 73, 74, 75, 81, 83, 84, 86, 88, 90, 91, 92, 97, 98, 102, 107,
#     110, 112, 114
# [4] 7, 8, 21, 22, 51, 68, 77, 78, 108, 111
# [5] 17, 20, 27, 56, 62, 65, 70, 76, 87, 95, 96, 113
# [6] 19, 29, 30, 35, 55, 79, 80, 82, 94, 101

# %%
#networkx
import networkx as nx
from networkx.algorithms import community
import matplotlib.pyplot as plt

G = nx.read_gml('football.gml')
# 可视化
nx.draw(G,with_labels=True)
plt.show()
# 社区发现
communities = list(community.label_propagation_communities(G))
print(len(communities))
print(communities)
# Out:
# 11
# [{'Akron', 'Kent', 'Ohio', 'Buffalo', 'BowlingGreenState', 'MiamiOhio', 'Connecticut', 'Marshall'}, {'NotreDame', 'BostonCollege', 'VirginiaTech', 'Navy', 'MiamiFlorida', 'Syracuse', 'Temple', 'WestVirginia', 'Rutgers', 'Pittsburgh'}, {'ColoradoState', 'SanDiegoState', 'BrighamYoung', 'Wyoming', 'NewMexico', 'AirForce', 'NevadaLasVegas', 'Utah'}, {'OhioState', 'Minnesota', 'Indiana', 'Purdue', 'Northwestern', 'PennState', 'MichiganState', 'Iowa', 'Michigan', 'Wisconsin', 'Illinois'}, {'Baylor', 'IowaState', 'OklahomaState', 'Oklahoma', 'Missouri', 'Nebraska', 'KansasState', 'Kansas', 'TexasA&M', 'Colorado', 'Texas', 'TexasTech'}, {'FloridaState', 'GeorgiaTech', 'Virginia', 'Maryland', 'Clemson', 'NorthCarolina', 'NorthCarolinaState', 'Duke', 'WakeForest'}, {'Idaho', 'UCLA', 'ArkansasState', 'NewMexicoState', 'Stanford', 'BoiseState', 'UtahState', 'NorthTexas', 'ArizonaState', 'WashingtonState', 'SouthernCalifornia', 'Arizona', 'Oregon', 'OregonState', 'California', 'Washington'}, {'Louisville', 'Army', 'Cincinnati', 'EastCarolina', 'Memphis', 'Houston', 'AlabamaBirmingham', 'SouthernMississippi', 'Tulane'}, {'SouthCarolina', 'MiddleTennesseeState', 'Auburn', 'LouisianaTech', 'LouisianaState', 'Kentucky', 'Georgia', 'Arkansas', 'Tennessee', 'Mississippi', 'CentralFlorida', 'Florida', 'MississippiState', 'LouisianaMonroe', 'LouisianaLafayette', 'Alabama', 'Vanderbilt'}, {'Hawaii', 'Nevada', 'TexasElPaso', 'FresnoState', 'SouthernMethodist', 'SanJoseState', 'Tulsa', 'TexasChristian', 'Rice'}, {'WesternMichigan', 'CentralMichigan', 'NorthernIllinois', 'Toledo', 'BallState', 'EasternMichigan'}]
